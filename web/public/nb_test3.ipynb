# %% [markdown]
# # Quick intro
#
# ## This notebook is extending (and changing a lot) of my [notebook-walkthrough for quantile regression with LR-Schedulers and model-checkpoints](https://www.kaggle.com/chrisden/6-82-quantile-reg-lr-schedulers-checkpoints).
# ## The goal of this Notebook is to introduce several methods for hyperparameter-optimization backed with cross-validation. For this goal, a lot of code the orginial code will be hidden (of course you can open it) and shortcutted to enhance readbility.

# %% [markdown]
# ## Update history:
# V30: Final version
# V25: Improvements in logging & ensembling
# V20: Enhanced logging, ENSEMBLING!
# V16: Several improvements, getting better results now!
# V10: Introduced usage of tensorflow.addons (tfa): WeightNormalization
# V7&8: Added support for maximizing cv-score or minimizing val_loss; added TODOS
# V6: Fixed an important bug: Hyperparameter search should MAXIMIZE score (was set to MINIMIZE due to copy paste)
# V5: Formatting, correcting typos.
# V2,3,4: Fast consequitive runs for fixing minor bugs, formatting, correcting typos.
# V1: Initial commit

# %% [markdown]
# ## Domain knowledge
#
# ### Some domain knowledge can be gained from watching the following video and from reading [here.](https://www.kaggle.com/c/osic-pulmonary-fibrosis-progression/discussion/165727)

# %%
from IPython.display import HTML
HTML('<center><iframe width="560" height="315" src="https://www.youtube.com/embed/AfK9LPNj-Zo" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>')
# Out:
# <center><iframe width="560" height="315" src="https://www.youtube.com/embed/AfK9LPNj-Zo" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></center>

# %% [markdown]
# ## Load all dependencies you need
# <span style="color:darkgreen ;font-family: Impact; font-size:13;"> from  </span> coffee  <span style="color:darkgreen ;font-family: Impact; font-size:13;"> import  </span> *****

# %%
import numpy as np
import random
import pandas as pd
import pydicom
import os
import matplotlib.pyplot as plt
from timeit import timeit
from tqdm import tqdm
from PIL import Image

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold, GroupKFold, StratifiedKFold

#color
from colorama import Fore, Back, Style

import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras.layers as Layers
import warnings
warnings.filterwarnings('ignore') #Ignore "future" warnings and Data-Frame-Slicing warnings.

# %%
def seed_everything(seed): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
seed_everything(2000)

# %% [markdown]
# # First glimpse at the data

# %%
ROOT = '../input/osic-pulmonary-fibrosis-progression'

train_df = pd.read_csv(f'{ROOT}/train.csv')
print(f'Train data has {train_df.shape[0]} rows and {train_df.shape[1]} columnns and looks like this:')
# Out:
# Train data has 1549 rows and 7 columnns and looks like this:

# %%
train_df.sample(5)
# Out:
#                         Patient  Weeks   FVC    Percent  Age     Sex  \
# 856   ID00224637202259281193413     39  2656  56.820127   72    Male
# 120   ID00030637202181211009029     36  2595  61.289561   69    Male
# 1199  ID00335637202286784464927     10  2557  69.093169   74    Male
# 1180  ID00329637202285906759848     47  2838  67.028814   69    Male
# 1266  ID00343637202287577133798     79  1511  65.778590   68  Female
#
#      SmokingStatus
# 856   Never smoked
# 120      Ex-smoker
# 1199     Ex-smoker
# 1180     Ex-smoker
# 1266  Never smoked

# %% [markdown]
# # Data Wrangling

# %%
train_unique_df = train_df.drop_duplicates(subset = ['Patient'], keep = 'first')
#train_unique_df.head()

# %%
# CHECK FOR DUPLICATES & DEAL WITH THEM
# keep = False: All duplicates will be shown
dupRows_df = train_df[train_df.duplicated(subset = ['Patient', 'Weeks'], keep = False )]
# dupRows_df.head()

# %%
train_df.drop_duplicates(subset=['Patient','Weeks'], keep = False, inplace = True)

# %%
print(f'So there are {dupRows_df.shape[0]} (= {dupRows_df.shape[0] / train_df.shape[0] * 100:.2f}%) duplicates.')
# Out:
# So there are 14 (= 0.91%) duplicates.

# %%
test_df = pd.read_csv(f'{ROOT}/test.csv')
print(f'Test data has {test_df.shape[0]} rows and {test_df.shape[1]} columnns, has no duplicates and looks like this:')
test_df.head()
# Out:
# Test data has 5 rows and 7 columnns, has no duplicates and looks like this:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00419637202311204720264      6  3020  70.186855   73  Male     Ex-smoker
# 1  ID00421637202311550012437     15  2739  82.045291   68  Male     Ex-smoker
# 2  ID00422637202311677017371      6  1930  76.672493   73  Male     Ex-smoker
# 3  ID00423637202312137826377     17  3294  79.258903   72  Male     Ex-smoker
# 4  ID00426637202313170790466      0  2925  71.824968   73  Male  Never smoked

# %% [markdown]
# ## Getting the format right

# %% [markdown]
# In this section we are going to do all the Data-Wrangling and pre-processing. For this we are going to define some functions and transformations, which then are applied to the data.
# It's good practice to concatinate all tabular data (train, test, submission), to ensure all data get's the same & correct treatment.
# If you don't do that, you need to be careful with some steps, e.g.:
# * Standardization or Normalization (e.g. MinMax Scaling) in ```test_df``` will not have the same range of values (e.g. min/max values) and therefore scaling than in ```train_df```.
# * The categorical features might have different categories in ```test_df``` than in ```train_df``` (e.g. ```test_df``` only contains male, Ex-smokers).
#
# So let's concatinate all our data first and then start with the transformations.
# ### The functions for this are hidden, as the focus for this notebook is the RandomCV hyperparameter optimization.

# %%
## CHECK SUBMISSION FORMAT
sub_df = pd.read_csv(f"{ROOT}/sample_submission.csv")

print(f"The sample submission contains: {sub_df.shape[0]} rows and {sub_df.shape[1]} columns.")
# Out:
# The sample submission contains: 730 rows and 3 columns.

# %%
# sub_df.head()

# %%
# split Patient_Week Column and re-arrage columns
sub_df[['Patient','Weeks']] = sub_df.Patient_Week.str.split("_",expand = True)
sub_df =  sub_df[['Patient','Weeks','Confidence', 'Patient_Week']]

# %%
sub_df = sub_df.merge(test_df.drop('Weeks', axis = 1), on = "Patient")

# %%
# introduce a column to indicate the source (train/test) for the data
train_df['Source'] = 'train'
sub_df['Source'] = 'test'

data_df = train_df.append([sub_df])
data_df.reset_index(inplace = True)
#data_df.head()

# %%
def get_baseline_week(df):
    # make a copy to not change original df    
    _df = df.copy()
    # ensure all Weeks values are INT and not accidentaly saved as string
    _df['Weeks'] = _df['Weeks'].astype(int)
    # as test data is containing all weeks, 
    _df.loc[_df.Source == 'test','min_week'] = np.nan
    _df["min_week"] = _df.groupby('Patient')['Weeks'].transform('min')
    _df['baselined_week'] = _df['Weeks'] - _df['min_week']
    
    return _df

# %%
data_df = get_baseline_week(data_df)
#data_df.head()

# %%
def get_baseline_FVC_old(df):
    # copy the DF to not in-place change the original one
    _df = df.copy()
    # get only the rows containing the baseline (= min_weeks) and therefore the baseline FVC
    baseline = _df.loc[_df.Weeks == _df.min_week]
    baseline = baseline[['Patient','FVC']].copy()
    baseline.columns = ['Patient','base_FVC']      
    
    # fill the df with the baseline FVC values
    for idx in _df.index:
        patient_id = _df.at[idx,'Patient']
        _df.at[idx,'base_FVC'] = baseline.loc[baseline.Patient == patient_id, 'base_FVC'].iloc[0]
    _df.drop(['min_week'], axis = 1)
    
    return _df

# %%
def get_baseline_FVC(df):
    # same as above
    _df = df.copy()
    base = _df.loc[_df.Weeks == _df.min_week]
    base = base[['Patient','FVC']].copy()
    base.columns = ['Patient','base_FVC']
    
    # add a row which contains the cumulated sum of rows for each patient
    base['nb'] = 1
    base['nb'] = base.groupby('Patient')['nb'].transform('cumsum')
    
    # drop all except the first row for each patient (= unique rows!), containing the min_week
    base = base[base.nb == 1]
    base.drop('nb', axis = 1, inplace = True)
    
    # merge the rows containing the base_FVC on the original _df
    _df = _df.merge(base, on = 'Patient', how = 'left')    
    _df.drop(['min_week'], axis = 1)
    
    return _df

# %%
def old_baseline_FVC():
    return get_baseline_FVC_old(data_df)
    pass

def new_baseline_FVC():
    return get_baseline_FVC(data_df)
    

duration_old = timeit(old_baseline_FVC, number = 3)
duration_new = timeit(new_baseline_FVC, number = 3)

#print(f"Taking the old, non-vectorized version took {duration_old / 3:.2f} sec, while the vectorized version only took {duration_new / 3:.3f} sec. That's {duration_old/duration_new:.0f} times faster!" )

# %%
data_df = get_baseline_FVC(data_df)
data_df.head()
# Out:
#    index                    Patient  Weeks   FVC    Percent  Age   Sex  \
# 0      0  ID00007637202177411956430     -4  2315  58.253649   79  Male
# 1      1  ID00007637202177411956430      5  2214  55.712129   79  Male
# 2      2  ID00007637202177411956430      7  2061  51.862104   79  Male
# 3      3  ID00007637202177411956430      9  2144  53.950679   79  Male
# 4      4  ID00007637202177411956430     11  2069  52.063412   79  Male
#
#   SmokingStatus Source  Confidence Patient_Week  min_week  baselined_week  \
# 0     Ex-smoker  train         NaN          NaN        -4               0
# 1     Ex-smoker  train         NaN          NaN        -4               9
# 2     Ex-smoker  train         NaN          NaN        -4              11
# 3     Ex-smoker  train         NaN          NaN        -4              13
# 4     Ex-smoker  train         NaN          NaN        -4              15
#
#    base_FVC
# 0      2315
# 1      2315
# 2      2315
# 3      2315
# 4      2315

# %% [markdown]
# Now the data has the format we need to work with.
# In the next section, we go trough two possibilities on how to normalize, standardize and prepare the data for the neural Network.

# %% [markdown]
# ## Preparing the data for the Neural Network

# %% [markdown]
# ### Let's do the Data-Prep and all related legwork ourselfs, w/o sklearn. How to use sklearn, you can read here:
# https://www.kaggle.com/chrisden/6-82-quantile-reg-lr-schedulers-checkpoints
#
# The good thing is: we dont need a NoTransformer here, as we simply can work in the DataFrame itself and not change any data which we want to preserve.
# Downside is, we need to implement the MinMaxScaler by hand. Make sure to not call it MinMaxScaler and shadow the already important MinMaxScaler from Sklearn!

# %%
def own_MinMaxColumnScaler(df, columns):
    """Adds columns with scaled numeric values to range [0, 1]
    using the formula X_scld = (X - X.min) / (X.max - X.min)"""
    for col in columns:
        new_col_name = col + '_scld'
        col_min = df[col].min()
        col_max = df[col].max()        
        df[new_col_name] = (df[col] - col_min) / ( col_max - col_min )

# %%
def own_OneHotColumnCreator(df, columns):
    """OneHot Encodes categorical features. Adds a column for each unique value per column"""
    for col in cat_attribs:
        for value in df[col].unique():
            df[value] = (df[col] == value).astype(int)

# %%
## APPLY DEFINED TRANSFORMATIONS
# define which attributes shall not be transformed, are numeric or categorical
no_transform_attribs = ['Patient', 'Weeks', 'min_week']
num_attribs = ['FVC', 'Percent', 'Age', 'baselined_week', 'base_FVC']
cat_attribs = ['Sex', 'SmokingStatus']

own_MinMaxColumnScaler(data_df, num_attribs)
own_OneHotColumnCreator(data_df, cat_attribs)

data_df[data_df.Source != "train"].head()
# Out:
#       index                    Patient  Weeks   FVC    Percent  Age   Sex  \
# 1535      0  ID00419637202311204720264    -12  3020  70.186855   73  Male
# 1536      1  ID00419637202311204720264    -11  3020  70.186855   73  Male
# 1537      2  ID00419637202311204720264    -10  3020  70.186855   73  Male
# 1538      3  ID00419637202311204720264     -9  3020  70.186855   73  Male
# 1539      4  ID00419637202311204720264     -8  3020  70.186855   73  Male
#
#      SmokingStatus Source  Confidence  ...  FVC_scld  Percent_scld  Age_scld  \
# 1535     Ex-smoker   test       100.0  ...  0.393575      0.332421  0.615385
# 1536     Ex-smoker   test       100.0  ...  0.393575      0.332421  0.615385
# 1537     Ex-smoker   test       100.0  ...  0.393575      0.332421  0.615385
# 1538     Ex-smoker   test       100.0  ...  0.393575      0.332421  0.615385
# 1539     Ex-smoker   test       100.0  ...  0.393575      0.332421  0.615385
#
#       baselined_week_scld  base_FVC_scld  Male  Female  Ex-smoker  \
# 1535             0.000000         0.3724     1       0          1
# 1536             0.006897         0.3724     1       0          1
# 1537             0.013793         0.3724     1       0          1
# 1538             0.020690         0.3724     1       0          1
# 1539             0.027586         0.3724     1       0          1
#
#       Never smoked  Currently smokes
# 1535             0                 0
# 1536             0                 0
# 1537             0                 0
# 1538             0                 0
# 1539             0                 0
#
# [5 rows x 24 columns]

# %%
# get back original data split
train_df = data_df.loc[data_df.Source == 'train']
sub = data_df.loc[data_df.Source == 'test']

# %% [markdown]
# # Model & Loss
# In this section we are going to define the loss & a first model.
# First we are taking care of the loss. We are trying to minimize the following:
#
# ![image.png](attachment:image.png)
#
# The global minimum of this function is achieved for delta = 0 and sigma = 70, which [results in a loss of roughly -4.59.](https://www.kaggle.com/c/osic-pulmonary-fibrosis-progression/discussion/168469).
#
# Getting our model to predict the Confidence and FVC values (which is what we need!) is not working fine so far, as you can read [here](https://www.kaggle.com/c/osic-pulmonary-fibrosis-progression/discussion/167764).
# Currently the way to go seems to be pinball loss.

# %% [markdown]
# # <font color='blue'>CONFIG Section </font>

# %% [markdown]
# In this section you can configure the following:
# * Features used for training
# * Basic training setup: BATCH_SIZE and EPOCHS,
# * Configuration for the loss function
# * Optimizers, Learning-Rate-Schedulers incl. Learning Rate start- & endpoint
# * Custom Logging Callback
# * Checkpoint-Saving Callback
#
# The Learning-Rate scheduler below is inspired by Chris great [Melanoma-detection notebook](https://www.kaggle.com/cdeotte/triple-stratified-kfold-with-tfrecords).
# Feel free to experiment with the scheduler and it's max/min and decay values.
#
# **Ever wondered why lr_max is scaled by BATCH_SIZE and therefore bigger for larger batches?** The reason for this is the following: the larger the BATCH_SIZE, the more averaged & smoothened a step of gradient decent is and the bigger our confidence in the *direction* of the step is. As there is less "randomness" in a huge averaged batch (compared with for example Stochastic Gradient Decent (=SGD) with batch size = 1) and our confidence in the direction is higher, the learning rate can be bigger to advance fast to the optimum.

# %%
######## BASIC CONFIG --- THIS IS GOING TO BE OVERWRITTEN BY OUR PARAMETER SEARCH BELOW ########
#the purpose of this section is to set a base-model and initialize all values. The (random)-Grid search is going to overwrite many of those values.
# be careful, the resulsts are VERY SEED-DEPENDEND!
seed_everything(1949)


### Features: choose which features you want to use
features_list = ['baselined_week_scld', 'Percent_scld', 'Age_scld', 'base_FVC_scld', 'Male', 'Female', 'Ex-smoker', 'Never smoked', 'Currently smokes']

### Basics for training:
NFOLDS = 5
EPOCHS = 1000
BATCH_SIZE = 96


### LOSS; set tradeoff btw. Pinball-loss and adding score
_lambda = 0.8 # 0.8 default


### Optimizers
# choose ADAM or SGD
optimizer = 'ADAM'

### Learning Rate Scheduler
def get_lr_callback(BATCH_SIZE = 64,
                    lr_start   = 0.000001,
                    lr_max     = 0.00001,
                    lr_min     = 0.000001,
                    lr_ramp_percent =  0.3,
                    plot = False):
    """Returns a lr_scheduler callback which is used for training.
    Feel free to change the values below!
    """
    lr_start   = lr_start
    lr_max     = lr_max * BATCH_SIZE # higher batch size --> higher lr
    lr_min     = lr_min
    # lr_ramp_percent defines which percentage of all epochs are used for ramping up the LR to the max
    lr_ramp_ep = EPOCHS * lr_ramp_percent
    lr_sus_ep  = 0
    lr_decay   = 0.991

    def lr_scheduler(epoch):
            if epoch < lr_ramp_ep:
                lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

            elif epoch < lr_ramp_ep + lr_sus_ep:
                lr = lr_max

            else:
                lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

            return lr
    
    if plot == False:
        # get the Keras-required callback with our LR for training
        lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler,verbose = False)
        return lr_callback 
    
    else: 
        return lr_scheduler
    
# plot & check the LR-Scheulder for sanity-check
lr_scheduler_plot = get_lr_callback(BATCH_SIZE = 64, plot = True)
rng = [i for i in range(EPOCHS)]
y = [lr_scheduler_plot(x) for x in rng]
plt.plot(rng, y)
print(f"Default Learning rate scheduler: {y[0]:.3g} to {max(y):.3g} to {y[-1]:.3g}")


# logging & saving
LOGGING = True

# defining custom callbacks
class LogPrintingCallback(tf.keras.callbacks.Callback):
    
    # defining a class variable to ensure LogPrinting, evaluation & saving is consitent
    # choose between 'val_score' and 'val_loss'
    optimization_variable = 'val_loss'
    
    def on_train_begin(self, logs = None):
        #print("Training started for this fold")
        self.val_loss = []
        self.val_score = []        
        
    def on_epoch_end(self, epoch, logs = None):
        self.val_loss.append(logs['val_loss']) 
        self.val_score.append(logs['val_score'])
        """if epoch % 1000 == 0 or epoch == (EPOCHS -1 ):
            print(f"The average val-loss for epoch {epoch} is {logs['val_loss']:.2f}"
                  f" and the score is {logs['val_score']}")"""
            
    def on_train_end(self, logs = None):
        # get index of best epoch
        monitored_variable = self.val_loss if LogPrintingCallback.optimization_variable == 'val_loss' else self.val_score
        best_epoch = np.argmin(monitored_variable)        
        # get score in best epoch
        best_result_loss = self.val_loss[best_epoch]
        best_result_score = self.val_score[best_epoch]
        print(f"Best model was found and saved in epoch {best_epoch + 1} with val_loss: {best_result_loss} and val_score: {best_result_score} ") 
        
        
def get_checkpoint_saver_callback(iteration, fold):
    checkpt_saver = tf.keras.callbacks.ModelCheckpoint(
        f'iteration-{i}_fold-{fold}.h5',
        monitor = LogPrintingCallback.optimization_variable,  # can be 'val_score' or 'val_loss'
        verbose = 0,
        save_best_only = True,
        save_weights_only = True,
        mode = 'min',    
        save_freq = 'epoch')
    
    return checkpt_saver
# Out:
# Default Learning rate scheduler: 1e-06 to 0.00064 to 2.15e-06

# %% [markdown]
# # (RANDOM) Grid Search

# %% [markdown]
# In this section we define our search grid. We also want to clarify how long does it take to search through ALL combinations? How long does it take to go through a defined number of random-combinations (called ITERATIONS)? Can it be complete within the 6 hours runtime-cap on Kaggle.com, or do we need to switch to Google Colab?
#
# Let me start with a cool story I found about [random Grid search](https://www.dattocon.com/#atlanta):
#
# > This is the storyline of “Random search for hyperparameter optimization” by Bergstra and Bengio. [...] Random search wasn’t taken very seriously before. This is because it doesn’t search over all the grid points, so it cannot possibly beat the optimum found by grid search. But then came along Bergstra and Bengio. They showed that, in surprisingly many instances, random search performs about as well as grid search. All in all, trying 60 random points sampled from the grid seems to be good enough.
# >
# > In hindsight, there is a simple probabilistic explanation for the result: for any distribution over a sample space with a finite maximum, the maximum of 60 random observations lies within the top 5% of the true maximum, with 95% probability. That may sound complicated, but it’s not. Imagine the 5% interval around the true maximum. Now imagine that we sample points from his space and see if any of it lands within that maximum. Each random draw has a 5% chance of landing in that interval, if we draw n points independently, then the probability that all of them miss the desired interval is (1−0.05)n. So the probability that at least one of them succeeds in hitting the interval is 1 minus that quantity. We want at least a .95 probability of success. To figure out the number of draws we need, just solve for n in the equation:
#
# $$1 − (1−0.05) ^n > 0.95$$
#
# We get $n ⩾ 60$. Ta-da!
#
# > The moral of the story is: if the close-to-optimal region of hyperparameters occupies at least 5% of the grid surface, then random search with 60 trials will find that region with high probability!
#
#
# The below example is just an nice start: you can also add modifications to the Neural Network which is built below, such as: number of layers, number of neurons, dropout-chance.

# %%
def swap (a,b):
     return b, a

# %% [markdown]
# ## Random Grid Search config

# %%
######## (RANDOM) GRID SEARCH ########
# this value determins how many random combinations out of our param_grid are used for training
ITERATIONS = 60

param_grid = {
    'NFOLDS'    : [5],
    'EPOCHS'    : [800],
    'batch_size': [32, 64, 128, 256],
    'optimizer' : ['SGD', 'ADAM'],
    'dropout1' :  np.linspace(0.1, 0.5, 5),
    'dropout2' :  np.linspace(0.1, 0.4, 5),
    # _labmda is used in the loss function as trade-off for qloss and score
    '_lambda'   : np.linspace(0.5, 0.9, 5),
    'lr_start'  : np.linspace(0.00001, 0.0001, 5),
    # remember that lr_max is multiplied with BATCH_SIZE!
    'lr_max'    : np.linspace(0.00001, 0.0001, 5),
    'lr_min'    : np.linspace(0.00001, 0.0001, 5),
    # below value defines which percentage of all epochs are used for ramping up the LR to the max
    # and then declining starts
    'lr_ramp_percent': [0.3],
}

# iterate over the param_grid: set the values & print them out
for key, value in param_grid.items():
    exec(key + '= value[random.randint(0, len(value) - 1)]')
    print(f'{key} = {eval(key)}')

# squish illogical results
if (lr_min > lr_max * BATCH_SIZE):
    swap(lr_min,lr_max)
    print(f'lr_min: {lr_min}, lrmax: {lr_max}')
if (lr_start > lr_max * BATCH_SIZE):
    print(f'lr_start: {lr_start}, lrmax: {lr_max}' )
# Out:
# NFOLDS = 5
# EPOCHS = 800
# batch_size = 128
# optimizer = SGD
# dropout1 = 0.5
# dropout2 = 0.4
# _lambda = 0.7
# lr_start = 0.0001
# lr_max = 1e-05
# lr_min = 7.75e-05
# lr_ramp_percent = 0.3

# %%
# count possible combinations 
combinations = 1
for x in param_grid.values():
    combinations *= len(x)
print(f'There are {combinations} possible combinations to be calculated for {NFOLDS} folds!')

## calc. runtime in seconds, measured by %timeit
# average runtime is 415 sec/iteration with 1k epochs and 5 folds
avg_runtime_1k_epochs = 415
total_runtime = avg_runtime_1k_epochs * EPOCHS / 1000 * NFOLDS / 5 * combinations
total_runtime_iterations = avg_runtime_1k_epochs * EPOCHS / 1000 * NFOLDS / 5 * ITERATIONS
# comapring runtime to max-runtime (6h)
exeeds_limit = "EXEEDING" if (total_runtime_iterations / 3600) > 6 else "NOT EXEEDING"

print(f'To cover all combinations & folds it takes {total_runtime / 3600:.1f} hours to finish. \n'
      f'The defined number of {ITERATIONS} random combinations takes {total_runtime_iterations / 3600:.1f} hours and is {exeeds_limit} our Kaggle maximum runtime!')
# Out:
# There are 125000 possible combinations to be calculated for 5 folds!
# To cover all combinations & folds it takes 11527.8 hours to finish.
# The defined number of 60 random combinations takes 5.5 hours and is NOT EXEEDING our Kaggle maximum runtime!

# %% [markdown]
# ### Loss Function

# %%
# create constants for the loss function
C1, C2 = tf.constant(70, dtype='float32'), tf.constant(1000, dtype="float32")

# define competition metric
def score(y_true, y_pred):
    """Calculate the competition metric"""
    tf.dtypes.cast(y_true, tf.float32)
    tf.dtypes.cast(y_pred, tf.float32)
    sigma = y_pred[:, 2] - y_pred[:, 0]
    fvc_pred = y_pred[:, 1]
    
    sigma_clip = tf.maximum(sigma, C1)
    delta = tf.abs(y_true[:, 0] - fvc_pred)
    delta = tf.minimum(delta, C2)
    sq2 = tf.sqrt( tf.dtypes.cast(2, dtype = tf.float32) )
    metric = (delta / sigma_clip) * sq2 + tf.math.log(sigma_clip * sq2)
    return K.mean(metric)

# define pinball loss
def qloss(y_true, y_pred):
    """Calculate Pinball loss"""
    # IMPORTANT: define quartiles, feel free to change here!
    qs = [0.2, 0.50, 0.8]
    q = tf.constant(np.array([qs]), dtype = tf.float32)
    e = y_true - y_pred
    v = tf.maximum(q * e, (q-1) * e)
    return K.mean(v)

# combine competition metric and pinball loss to a joint loss function
def mloss(_lambda):
    """Combine Score and qloss"""
    def loss(y_true, y_pred):
        return _lambda * qloss(y_true, y_pred) + (1 - _lambda) * score(y_true, y_pred)
    return loss

# %% [markdown]
# # Model
# We are going to use weight-normalization (link to the paper, click [here](https://arxiv.org/abs/1602.07868)) from ```tensorflow_addons``` to support faster convergence.
# The authors describe the method like this:
# > Weight normalization: a reparameterization of the weight vectors in a neural network that decouples the length of those weight vectors from their direction. By reparameterizing the weights in this way we improve the conditioning of the optimization problem and we speed up convergence of stochastic gradient descent. Our reparameterization is inspired by batch normalization but does not introduce any dependencies between the examples in a minibatch.
#
# Additionally we gain more robustness for the choosing of the hyperparameter learning rate. Cited from page 3:
# > Empirically, we find that the ability to grow the norm ||v|| makes optimization of neural networks
# > with weight normalization very robust to the value of the learning rate: If the learning rate is too
# > large, the norm of the unnormalized weights grows quickly until an appropriate effective learning rate
# > is reached.
#
# As the given task without the usage of images is not very compute-intensive (you don't need a GPU, CPU will do), we will change the activation-function from 'relu' to 'elu'.
# For more info you can read [here](https://mlfromscratch.com/activation-functions-explained/#elu), below you can find a short summary:
#
# **Pros**
# * Avoids the "dead ReLu" problem: ReLus provides activation-values & gradients of 0 for negative input values
# * Produces activations for negative inputs instead of letting them be zero when calculating the gradient.
# * Produces negative outputs, which helps the network nudge weights and biases in the right directions for negative inputs, too.
#
# **Cons**
# * Introduces longer computation time, because of the exponential operation included.
# * Does not avoid the exploding gradient problem.

# %%
import tensorflow_addons as tfa

def get_model(optimizer = 'ADAM', dropout1 = 0.3, dropout2 = 0.2):
    "Creates and returns a model"
    # instantiate optimizer
    optimizer = tf.keras.optimizers.Adam(lr = 0.1) if optimizer == 'ADAM' else tf.keras.optimizers.SGD()

    # create model    
    inp = Layers.Input((len(features_list),), name = "Patient")
    x = Layers.BatchNormalization()(inp)
    x = tfa.layers.WeightNormalization(Layers.Dense(196, activation = "elu", name = "d1"))(x)
    x = Layers.BatchNormalization()(x)
    x = Layers.Dropout(dropout1)(x)
    x = tfa.layers.WeightNormalization(Layers.Dense(128, activation = "elu", name = "d2"))(x)
    x = Layers.BatchNormalization()(x)
    x = Layers.Dropout(dropout2)(x)
    # predicting the quantiles
    p1 = Layers.Dense(3, activation = "relu", name = "p1")(x)
    # quantile adjusting p1 predictions
    p2 = Layers.Dense(3, activation = "relu", name = "p2")(x)
    preds = Layers.Lambda(lambda x: x[0] + tf.cumsum(x[1], axis = 1), 
                     name = "preds")([p1, p2])
    
    model = tf.keras.Model(inputs = inp, outputs = preds, name = "NeuralNet")
    model.compile(loss = mloss(_lambda), optimizer = optimizer, metrics = [score])
    
    return model

# %%
## GET TRAINING DATA AND TARGET VALUE

# get target value
y = train_df['FVC'].values.astype(float)

# get training & test data
X_train = train_df[features_list].values
X_test = sub[features_list].values

# %% [markdown]
# In the following we want to create leak-free folds to get a robust **cross-validation strategy** in order to evaluate all our models & our training. The idea is to avoid having the same patient (= PatientID) in training- and in validation-Data, as this might lead to evaluate a higher CV-score for a model which is luckily learning/memorizing the data for a particular patientID which is also frequently occuring in the validation-data.
#
#
# The idea on how to do that is coming from @PAB97 [Pierre's great notebook (CHECK IT OUT!)](https://www.kaggle.com/rftexas/osic-eda-leak-free-kfold-cv-lgb-baseline#kln-440)
# Please note, that we still don't use proper stratification based on 'Age', 'Sex', 'SmokingStatus'.
#
# In the following code-blocks we are trying the specified amount (ITERATIONS) of random chosen hyper-parameter values, taken from our parameter-grid and train & evaluate the model. In the end, we make our prediction based on the best model. Additionally, we log all our results to have a better overview.

# %%
# Create a dict for saving training results
results_df = pd.DataFrame(columns = ['iteration', 'val_score', 'params', 'test_predictions'],
                              index = list(range(ITERATIONS)))

# %% [markdown]
# # Training

# %%
# measure execution time of training process
import time
start_time = time.time()

# %%
## Non-Stratified GroupKFold-split (can be further enhanced with stratification!)
"""K-fold variant with non-overlapping groups.
The same group will not appear in two different folds: in this case we dont want to have overlapping patientIDs in TRAIN and VAL-Data!
The folds are approximately balanced in the sense that the number of distinct groups is approximately the same in each fold."""

gkf = GroupKFold(n_splits = NFOLDS)
# extract Patient IDs for ensuring uniqueness of patients in each fold
groups = train_df['Patient'].values

for i in range(ITERATIONS):
    # create empty dict for logging
    params_iteration = {}
    val_scores = []
    
    # instantiate target arrays
    train_preds = np.zeros((X_train.shape[0], 3))
    test_preds = np.zeros((X_test.shape[0], 3))

    # iterate over the param_grid: set the new random values for this iteration and log them
    for key, value in param_grid.items():
        exec(key + '= value[random.randint(0, len(value) - 1)]')
        params_iteration[key] = {eval(key)}
          
    
    # correct illogical results
    if (lr_min > lr_max * BATCH_SIZE):
        swap(lr_min,lr_max)
        print(f'lr_min: {lr_min}, lrmax: {lr_max}')
    if (lr_start > lr_max * BATCH_SIZE):
        print(f'lr_start: {lr_start}, lrmax: {lr_max}' )

    # training and evaluation
    fold = 0
    for train_idx, val_idx in gkf.split(X_train, y, groups = groups):
        fold += 1
        print(f"ITERATION: {i}, FOLD {fold}:")

        # callbacks: logging & model saving with checkpoints each fold
        callbacks = [get_lr_callback(BATCH_SIZE = BATCH_SIZE,
                                     lr_start   = lr_start,
                                     lr_max     = lr_max * BATCH_SIZE,
                                     lr_min     = lr_min,
                                     lr_ramp_percent =  lr_ramp_percent,
                                     plot = False)]        

        if LOGGING == True:
            callbacks +=  [get_checkpoint_saver_callback(i,fold),                     
                         LogPrintingCallback()]

        # build and train model
        model = get_model(optimizer, dropout1, dropout2)
        model.fit(X_train[train_idx], y[train_idx], 
                  batch_size = BATCH_SIZE, 
                  epochs = EPOCHS, 
                  validation_data = (X_train[val_idx], y[val_idx]), 
                  callbacks = callbacks,
                  verbose = 0) 

        # load best model to make preds
        model.load_weights(f'iteration-{i}_fold-{fold}.h5')
        train_preds[val_idx] = model.predict(X_train[val_idx],
                                             batch_size = BATCH_SIZE,
                                             verbose = 0)
        
        val_scores.append(model.evaluate(X_train[val_idx], y[val_idx], verbose = 0, batch_size = BATCH_SIZE)[1])
        
        # predict on test set and average the predictions over all folds
        test_preds += model.predict(X_test, batch_size = BATCH_SIZE, verbose = 0) / NFOLDS
    
    print(f"{val_scores} #\n")
    val_score_iteration = np.mean(val_scores)
    # log results    
    results_df.at[i, 'iteration'] = i
    results_df.at[i, 'val_score'] = val_score_iteration
    results_df.at[i, 'params'] = str(params_iteration)
    results_df.at[i, 'test_predictions'] = test_preds
    # print(results)
# Out:
# ITERATION: 0, FOLD 1:
# Best model was found and saved in epoch 361 with val_loss: 33.32793426513672 and val_score: 6.781380653381348
# ITERATION: 0, FOLD 2:
# Best model was found and saved in epoch 575 with val_loss: 41.62712860107422 and val_score: 6.937734127044678
# ITERATION: 0, FOLD 3:
# Best model was found and saved in epoch 292 with val_loss: 32.89128494262695 and val_score: 6.752191543579102
# ITERATION: 0, FOLD 4:
# Best model was found and saved in epoch 359 with val_loss: 35.17921829223633 and val_score: 6.747386455535889
# ITERATION: 0, FOLD 5:
# Best model was found and saved in epoch 504 with val_loss: 36.258174896240234 and val_score: 6.793333530426025
# [6.781380653381348, 6.937734127044678, 6.752191543579102, 6.747386455535889, 6.793333530426025] #
#
# ITERATION: 1, FOLD 1:
# Best model was found and saved in epoch 275 with val_loss: 45.22630310058594 and val_score: 6.568347930908203
# ITERATION: 1, FOLD 2:
# Best model was found and saved in epoch 279 with val_loss: 55.995574951171875 and val_score: 6.761152744293213
# ITERATION: 1, FOLD 3:
# Best model was found and saved in epoch 120 with val_loss: 49.396461486816406 and val_score: 6.7389984130859375
# ITERATION: 1, FOLD 4:
# Best model was found and saved in epoch 324 with val_loss: 48.95219421386719 and val_score: 6.7431864738464355
# ITERATION: 1, FOLD 5:
# Best model was found and saved in epoch 255 with val_loss: 51.234519958496094 and val_score: 6.638820171356201
# [6.568347930908203, 6.761152744293213, 6.7389984130859375, 6.7431864738464355, 6.638820171356201] #
#
# ITERATION: 2, FOLD 1:
# Best model was found and saved in epoch 482 with val_loss: 44.956687927246094 and val_score: 6.737995147705078
# ITERATION: 2, FOLD 2:
# Best model was found and saved in epoch 549 with val_loss: 56.85028076171875 and val_score: 6.930714130401611
# ITERATION: 2, FOLD 3:
# Best model was found and saved in epoch 252 with val_loss: 44.90462875366211 and val_score: 6.703861713409424
# ITERATION: 2, FOLD 4:
# Best model was found and saved in epoch 335 with val_loss: 48.97297286987305 and val_score: 6.750848770141602
# ITERATION: 2, FOLD 5:
# Best model was found and saved in epoch 264 with val_loss: 54.2510986328125 and val_score: 6.889578342437744
# [6.737995147705078, 6.930714130401611, 6.703861713409424, 6.750848770141602, 6.889578342437744] #
#
# ITERATION: 3, FOLD 1:
# Best model was found and saved in epoch 525 with val_loss: 36.4132194519043 and val_score: 6.763485908508301
# ITERATION: 3, FOLD 2:
# Best model was found and saved in epoch 471 with val_loss: 46.05927658081055 and val_score: 6.86103630065918
# ITERATION: 3, FOLD 3:
# Best model was found and saved in epoch 140 with val_loss: 40.675987243652344 and val_score: 6.751181125640869
# ITERATION: 3, FOLD 4:
# Best model was found and saved in epoch 352 with val_loss: 35.801544189453125 and val_score: 6.5825958251953125
# ITERATION: 3, FOLD 5:
# Best model was found and saved in epoch 169 with val_loss: 41.37459945678711 and val_score: 6.802821159362793
# [6.763485908508301, 6.86103630065918, 6.751181125640869, 6.5825958251953125, 6.802821159362793] #
#
# ITERATION: 4, FOLD 1:
# Best model was found and saved in epoch 411 with val_loss: 36.609737396240234 and val_score: 6.739931583404541
# ITERATION: 4, FOLD 2:
# Best model was found and saved in epoch 280 with val_loss: 45.85328674316406 and val_score: 6.879916191101074
# ITERATION: 4, FOLD 3:
# Best model was found and saved in epoch 244 with val_loss: 38.59160232543945 and val_score: 6.6999030113220215
# ITERATION: 4, FOLD 4:
# Best model was found and saved in epoch 346 with val_loss: 38.02125549316406 and val_score: 6.706051826477051
# ITERATION: 4, FOLD 5:
# Best model was found and saved in epoch 208 with val_loss: 45.23881912231445 and val_score: 6.8688483238220215
# [6.739931583404541, 6.879916191101074, 6.6999030113220215, 6.706051826477051, 6.8688483238220215] #
#
# ITERATION: 5, FOLD 1:
# Best model was found and saved in epoch 389 with val_loss: 33.119590759277344 and val_score: 6.806685447692871
# ITERATION: 5, FOLD 2:
# Best model was found and saved in epoch 301 with val_loss: 40.6564826965332 and val_score: 6.892144203186035
# ITERATION: 5, FOLD 3:
# Best model was found and saved in epoch 271 with val_loss: 33.684967041015625 and val_score: 6.707793235778809
# ITERATION: 5, FOLD 4:
# Best model was found and saved in epoch 279 with val_loss: 33.2944221496582 and val_score: 6.716207504272461
# ITERATION: 5, FOLD 5:
# Best model was found and saved in epoch 165 with val_loss: 35.347869873046875 and val_score: 6.7709760665893555
# [6.806685447692871, 6.892144203186035, 6.707793235778809, 6.716207504272461, 6.7709760665893555] #
#
# ITERATION: 6, FOLD 1:
# Best model was found and saved in epoch 285 with val_loss: 31.82345962524414 and val_score: 6.670434951782227
# ITERATION: 6, FOLD 2:
# Best model was found and saved in epoch 287 with val_loss: 39.605712890625 and val_score: 6.840964317321777
# ITERATION: 6, FOLD 3:
# Best model was found and saved in epoch 165 with val_loss: 34.21416091918945 and val_score: 6.750665187835693
# ITERATION: 6, FOLD 4:
# Best model was found and saved in epoch 112 with val_loss: 35.08680725097656 and val_score: 6.6341729164123535
# ITERATION: 6, FOLD 5:
# Best model was found and saved in epoch 333 with val_loss: 40.74272155761719 and val_score: 6.7842631340026855
# [6.670434951782227, 6.840964317321777, 6.750665187835693, 6.6341729164123535, 6.7842631340026855] #
#
# ITERATION: 7, FOLD 1:
# Best model was found and saved in epoch 492 with val_loss: 28.455678939819336 and val_score: 6.751713275909424
# ITERATION: 7, FOLD 2:
# Best model was found and saved in epoch 498 with val_loss: 36.859439849853516 and val_score: 6.965795516967773
# ITERATION: 7, FOLD 3:
# Best model was found and saved in epoch 350 with val_loss: 29.770261764526367 and val_score: 6.7201714515686035
# ITERATION: 7, FOLD 4:
# Best model was found and saved in epoch 335 with val_loss: 29.92896270751953 and val_score: 6.757981300354004
# ITERATION: 7, FOLD 5:
# Best model was found and saved in epoch 364 with val_loss: 30.560373306274414 and val_score: 6.773351669311523
# [6.751713275909424, 6.965795516967773, 6.7201714515686035, 6.757981300354004, 6.773351669311523] #
#
# ITERATION: 8, FOLD 1:
# Best model was found and saved in epoch 554 with val_loss: 43.72380828857422 and val_score: 6.634653091430664
# ITERATION: 8, FOLD 2:
# Best model was found and saved in epoch 271 with val_loss: 55.355674743652344 and val_score: 6.730282306671143
# ITERATION: 8, FOLD 3:
# Best model was found and saved in epoch 73 with val_loss: 47.79534149169922 and val_score: 6.549170970916748
# ITERATION: 8, FOLD 4:
# Best model was found and saved in epoch 412 with val_loss: 49.69012451171875 and val_score: 6.630297660827637
# ITERATION: 8, FOLD 5:
# Best model was found and saved in epoch 128 with val_loss: 50.30515670776367 and val_score: 6.788290977478027
# [6.634653091430664, 6.730282306671143, 6.549170970916748, 6.630297660827637, 6.788290977478027] #
#
# ITERATION: 9, FOLD 1:
# Best model was found and saved in epoch 562 with val_loss: 38.0533561706543 and val_score: 6.628279209136963
# ITERATION: 9, FOLD 2:
# Best model was found and saved in epoch 726 with val_loss: 52.28362274169922 and val_score: 6.855469703674316
# ITERATION: 9, FOLD 3:
# Best model was found and saved in epoch 343 with val_loss: 43.7192268371582 and val_score: 6.739290237426758
# ITERATION: 9, FOLD 4:
# Best model was found and saved in epoch 363 with val_loss: 43.266563415527344 and val_score: 6.706178665161133
# ITERATION: 9, FOLD 5:
# Best model was found and saved in epoch 55 with val_loss: 45.19794845581055 and val_score: 6.73828125
# [6.628279209136963, 6.855469703674316, 6.739290237426758, 6.706178665161133, 6.73828125] #
#
# ITERATION: 10, FOLD 1:
# Best model was found and saved in epoch 481 with val_loss: 44.32327651977539 and val_score: 6.71235990524292
# ITERATION: 10, FOLD 2:
# Best model was found and saved in epoch 464 with val_loss: 57.0228385925293 and val_score: 6.849855899810791
# ITERATION: 10, FOLD 3:
# Best model was found and saved in epoch 85 with val_loss: 47.27128219604492 and val_score: 6.694697380065918
# ITERATION: 10, FOLD 4:
# Best model was found and saved in epoch 141 with val_loss: 46.724098205566406 and val_score: 6.719360828399658
# ITERATION: 10, FOLD 5:
# Best model was found and saved in epoch 75 with val_loss: 46.62919235229492 and val_score: 6.703429222106934
# [6.71235990524292, 6.849855899810791, 6.694697380065918, 6.719360828399658, 6.703429222106934] #
#
# ITERATION: 11, FOLD 1:
# Best model was found and saved in epoch 375 with val_loss: 30.95008659362793 and val_score: 6.574264049530029
# ITERATION: 11, FOLD 2:
# Best model was found and saved in epoch 283 with val_loss: 39.9599723815918 and val_score: 6.800278663635254
# ITERATION: 11, FOLD 3:
# Best model was found and saved in epoch 156 with val_loss: 32.748008728027344 and val_score: 6.605052471160889
# ITERATION: 11, FOLD 4:
# Best model was found and saved in epoch 614 with val_loss: 32.925846099853516 and val_score: 6.695433616638184
# ITERATION: 11, FOLD 5:
# Best model was found and saved in epoch 132 with val_loss: 34.20691680908203 and val_score: 6.67709493637085
# [6.574264049530029, 6.800278663635254, 6.605052471160889, 6.695433616638184, 6.67709493637085] #
#
# ITERATION: 12, FOLD 1:
# Best model was found and saved in epoch 532 with val_loss: 30.984378814697266 and val_score: 6.673020362854004
# ITERATION: 12, FOLD 2:
# Best model was found and saved in epoch 140 with val_loss: 40.519012451171875 and val_score: 6.804116249084473
# ITERATION: 12, FOLD 3:
# Best model was found and saved in epoch 75 with val_loss: 35.698997497558594 and val_score: 6.817127227783203
# ITERATION: 12, FOLD 4:
# Best model was found and saved in epoch 336 with val_loss: 33.82974624633789 and val_score: 6.694337844848633
# ITERATION: 12, FOLD 5:
# Best model was found and saved in epoch 358 with val_loss: 34.46229934692383 and val_score: 6.650996685028076
# [6.673020362854004, 6.804116249084473, 6.817127227783203, 6.694337844848633, 6.650996685028076] #
#
# ITERATION: 13, FOLD 1:
# Best model was found and saved in epoch 351 with val_loss: 26.924692153930664 and val_score: 6.684645652770996
# ITERATION: 13, FOLD 2:
# Best model was found and saved in epoch 302 with val_loss: 35.544403076171875 and val_score: 6.860912799835205
# ITERATION: 13, FOLD 3:
# Best model was found and saved in epoch 218 with val_loss: 28.651453018188477 and val_score: 6.674129962921143
# ITERATION: 13, FOLD 4:
# Best model was found and saved in epoch 478 with val_loss: 28.00949478149414 and val_score: 6.638859748840332
# ITERATION: 13, FOLD 5:
# Best model was found and saved in epoch 95 with val_loss: 30.51877784729004 and val_score: 6.73898983001709
# [6.684645652770996, 6.860912799835205, 6.674129962921143, 6.638859748840332, 6.73898983001709] #
#
# ITERATION: 14, FOLD 1:
# Best model was found and saved in epoch 562 with val_loss: 35.84569549560547 and val_score: 6.677600383758545
# ITERATION: 14, FOLD 2:
# Best model was found and saved in epoch 280 with val_loss: 46.11714172363281 and val_score: 6.905240058898926
# ITERATION: 14, FOLD 3:
# Best model was found and saved in epoch 161 with val_loss: 41.62339782714844 and val_score: 6.849536895751953
# ITERATION: 14, FOLD 4:
# Best model was found and saved in epoch 468 with val_loss: 36.84191131591797 and val_score: 6.656503200531006
# ITERATION: 14, FOLD 5:
# Best model was found and saved in epoch 301 with val_loss: 41.24760818481445 and val_score: 6.748077869415283
# [6.677600383758545, 6.905240058898926, 6.849536895751953, 6.656503200531006, 6.748077869415283] #
#
# ITERATION: 15, FOLD 1:
# Best model was found and saved in epoch 406 with val_loss: 46.728878021240234 and val_score: 6.758082389831543
# ITERATION: 15, FOLD 2:
# Best model was found and saved in epoch 337 with val_loss: 57.44626235961914 and val_score: 6.902712345123291
# ITERATION: 15, FOLD 3:
# Best model was found and saved in epoch 212 with val_loss: 52.9625358581543 and val_score: 6.912280559539795
# ITERATION: 15, FOLD 4:
# Best model was found and saved in epoch 347 with val_loss: 50.713626861572266 and val_score: 6.781980037689209
# ITERATION: 15, FOLD 5:
# Best model was found and saved in epoch 198 with val_loss: 49.492374420166016 and val_score: 6.800061225891113
# [6.758082389831543, 6.902712345123291, 6.912280559539795, 6.781980037689209, 6.800061225891113] #
#
# ITERATION: 16, FOLD 1:
# Best model was found and saved in epoch 525 with val_loss: 35.474430084228516 and val_score: 6.637917995452881
# ITERATION: 16, FOLD 2:
# Best model was found and saved in epoch 301 with val_loss: 45.503936767578125 and val_score: 6.8211212158203125
# ITERATION: 16, FOLD 3:
# Best model was found and saved in epoch 107 with val_loss: 38.34968185424805 and val_score: 6.643089294433594
# ITERATION: 16, FOLD 4:
# Best model was found and saved in epoch 91 with val_loss: 38.491294860839844 and val_score: 6.723595142364502
# ITERATION: 16, FOLD 5:
# Best model was found and saved in epoch 381 with val_loss: 37.56678009033203 and val_score: 6.633735656738281
# [6.637917995452881, 6.8211212158203125, 6.643089294433594, 6.723595142364502, 6.633735656738281] #
#
# ITERATION: 17, FOLD 1:
# Best model was found and saved in epoch 564 with val_loss: 37.73490524291992 and val_score: 6.674799919128418
# ITERATION: 17, FOLD 2:
# Best model was found and saved in epoch 98 with val_loss: 45.19573974609375 and val_score: 6.817776679992676
# ITERATION: 17, FOLD 3:
# Best model was found and saved in epoch 241 with val_loss: 40.0861701965332 and val_score: 6.673958778381348
# ITERATION: 17, FOLD 4:
# Best model was found and saved in epoch 229 with val_loss: 37.77452087402344 and val_score: 6.7065205574035645
# ITERATION: 17, FOLD 5:
# Best model was found and saved in epoch 39 with val_loss: 40.928401947021484 and val_score: 6.661800384521484
# [6.674799919128418, 6.817776679992676, 6.673958778381348, 6.7065205574035645, 6.661800384521484] #
#
# ITERATION: 18, FOLD 1:
# Best model was found and saved in epoch 522 with val_loss: 44.718528747558594 and val_score: 6.7417707443237305
# ITERATION: 18, FOLD 2:
# Best model was found and saved in epoch 622 with val_loss: 58.122779846191406 and val_score: 6.882966041564941
# ITERATION: 18, FOLD 3:
# Best model was found and saved in epoch 378 with val_loss: 51.68560028076172 and val_score: 6.821289539337158
# ITERATION: 18, FOLD 4:
# Best model was found and saved in epoch 499 with val_loss: 46.80636215209961 and val_score: 6.73720645904541
# ITERATION: 18, FOLD 5:
# Best model was found and saved in epoch 49 with val_loss: 49.21565246582031 and val_score: 6.790870189666748
# [6.7417707443237305, 6.882966041564941, 6.821289539337158, 6.73720645904541, 6.790870189666748] #
#
# ITERATION: 19, FOLD 1:
# Best model was found and saved in epoch 251 with val_loss: 42.24715805053711 and val_score: 6.5439958572387695
# ITERATION: 19, FOLD 2:
# Best model was found and saved in epoch 544 with val_loss: 57.18922805786133 and val_score: 6.796885967254639
# ITERATION: 19, FOLD 3:
# Best model was found and saved in epoch 189 with val_loss: 47.48097229003906 and val_score: 6.589219093322754
# ITERATION: 19, FOLD 4:
# Best model was found and saved in epoch 335 with val_loss: 50.23817443847656 and val_score: 6.648930072784424
# ITERATION: 19, FOLD 5:
# Best model was found and saved in epoch 78 with val_loss: 46.88163757324219 and val_score: 6.653410911560059
# [6.5439958572387695, 6.796885967254639, 6.589219093322754, 6.648930072784424, 6.653410911560059] #
#
# ITERATION: 20, FOLD 1:
# Best model was found and saved in epoch 463 with val_loss: 26.965641021728516 and val_score: 6.690816879272461
# ITERATION: 20, FOLD 2:
# Best model was found and saved in epoch 397 with val_loss: 37.59429931640625 and val_score: 6.9152069091796875
# ITERATION: 20, FOLD 3:
# Best model was found and saved in epoch 236 with val_loss: 27.159709930419922 and val_score: 6.632856845855713
# ITERATION: 20, FOLD 4:
# Best model was found and saved in epoch 311 with val_loss: 29.2204647064209 and val_score: 6.7005839347839355
# ITERATION: 20, FOLD 5:
# Best model was found and saved in epoch 161 with val_loss: 29.62531089782715 and val_score: 6.703356742858887
# [6.690816879272461, 6.9152069091796875, 6.632856845855713, 6.7005839347839355, 6.703356742858887] #
#
# ITERATION: 21, FOLD 1:
# Best model was found and saved in epoch 228 with val_loss: 25.70478630065918 and val_score: 6.54909086227417
# ITERATION: 21, FOLD 2:
# Best model was found and saved in epoch 238 with val_loss: 34.4671745300293 and val_score: 6.7961039543151855
# ITERATION: 21, FOLD 3:
# Best model was found and saved in epoch 173 with val_loss: 35.50738525390625 and val_score: 6.661428451538086
# ITERATION: 21, FOLD 4:
# Best model was found and saved in epoch 223 with val_loss: 28.773616790771484 and val_score: 6.6194963455200195
# ITERATION: 21, FOLD 5:
# Best model was found and saved in epoch 169 with val_loss: 30.81920051574707 and val_score: 6.631657600402832
# [6.54909086227417, 6.7961039543151855, 6.661428451538086, 6.6194963455200195, 6.631657600402832] #
#
# ITERATION: 22, FOLD 1:
# Best model was found and saved in epoch 472 with val_loss: 34.22940444946289 and val_score: 6.659653663635254
# ITERATION: 22, FOLD 2:
# Best model was found and saved in epoch 270 with val_loss: 43.248512268066406 and val_score: 6.790311336517334
# ITERATION: 22, FOLD 3:
# Best model was found and saved in epoch 275 with val_loss: 39.921844482421875 and val_score: 6.691885948181152
# ITERATION: 22, FOLD 4:
# Best model was found and saved in epoch 355 with val_loss: 37.28105163574219 and val_score: 6.631500720977783
# ITERATION: 22, FOLD 5:
# Best model was found and saved in epoch 149 with val_loss: 36.2454948425293 and val_score: 6.56948709487915
# [6.659653663635254, 6.790311336517334, 6.691885948181152, 6.631500720977783, 6.56948709487915] #
#
# ITERATION: 23, FOLD 1:
# Best model was found and saved in epoch 562 with val_loss: 40.542442321777344 and val_score: 6.670210361480713
# ITERATION: 23, FOLD 2:
# Best model was found and saved in epoch 337 with val_loss: 52.982765197753906 and val_score: 6.940516948699951
# ITERATION: 23, FOLD 3:
# Best model was found and saved in epoch 484 with val_loss: 45.88676071166992 and val_score: 6.72719669342041
# ITERATION: 23, FOLD 4:
# Best model was found and saved in epoch 459 with val_loss: 43.6777458190918 and val_score: 6.657055377960205
# ITERATION: 23, FOLD 5:
# Best model was found and saved in epoch 362 with val_loss: 47.168087005615234 and val_score: 6.826548099517822
# [6.670210361480713, 6.940516948699951, 6.72719669342041, 6.657055377960205, 6.826548099517822] #
#
# ITERATION: 24, FOLD 1:
# Best model was found and saved in epoch 307 with val_loss: 37.00547790527344 and val_score: 6.748899936676025
# ITERATION: 24, FOLD 2:
# Best model was found and saved in epoch 266 with val_loss: 46.3304557800293 and val_score: 6.876587867736816
# ITERATION: 24, FOLD 3:
# Best model was found and saved in epoch 136 with val_loss: 40.55180740356445 and val_score: 6.796144008636475
# ITERATION: 24, FOLD 4:
# Best model was found and saved in epoch 340 with val_loss: 39.84251022338867 and val_score: 6.768646240234375
# ITERATION: 24, FOLD 5:
# Best model was found and saved in epoch 134 with val_loss: 39.69173812866211 and val_score: 6.756182670593262
# [6.748899936676025, 6.876587867736816, 6.796144008636475, 6.768646240234375, 6.756182670593262] #
#
# ITERATION: 25, FOLD 1:
# Best model was found and saved in epoch 522 with val_loss: 43.80012130737305 and val_score: 6.5950541496276855
# ITERATION: 25, FOLD 2:
# Best model was found and saved in epoch 80 with val_loss: 57.37063980102539 and val_score: 6.900026321411133
# ITERATION: 25, FOLD 3:
# Best model was found and saved in epoch 67 with val_loss: 50.135597229003906 and val_score: 6.759251594543457
# ITERATION: 25, FOLD 4:
# Best model was found and saved in epoch 626 with val_loss: 48.028594970703125 and val_score: 6.648976802825928
# ITERATION: 25, FOLD 5:
# Best model was found and saved in epoch 93 with val_loss: 49.90432357788086 and val_score: 6.7353410720825195
# [6.5950541496276855, 6.900026321411133, 6.759251594543457, 6.648976802825928, 6.7353410720825195] #
#
# ITERATION: 26, FOLD 1:
# Best model was found and saved in epoch 416 with val_loss: 28.239187240600586 and val_score: 6.738663673400879
# ITERATION: 26, FOLD 2:
# Best model was found and saved in epoch 431 with val_loss: 36.604736328125 and val_score: 6.94085693359375
# ITERATION: 26, FOLD 3:
# Best model was found and saved in epoch 303 with val_loss: 30.680805206298828 and val_score: 6.777823448181152
# ITERATION: 26, FOLD 4:
# Best model was found and saved in epoch 499 with val_loss: 30.774818420410156 and val_score: 6.780725479125977
# ITERATION: 26, FOLD 5:
# Best model was found and saved in epoch 364 with val_loss: 32.512794494628906 and val_score: 6.873666763305664
# [6.738663673400879, 6.94085693359375, 6.777823448181152, 6.780725479125977, 6.873666763305664] #
#
# ITERATION: 27, FOLD 1:
# Best model was found and saved in epoch 251 with val_loss: 31.09103012084961 and val_score: 6.596162796020508
# ITERATION: 27, FOLD 2:
# Best model was found and saved in epoch 409 with val_loss: 39.859535217285156 and val_score: 6.840442180633545
# ITERATION: 27, FOLD 3:
# Best model was found and saved in epoch 223 with val_loss: 38.63469696044922 and val_score: 6.830387115478516
# ITERATION: 27, FOLD 4:
# Best model was found and saved in epoch 151 with val_loss: 32.64228057861328 and val_score: 6.5798258781433105
# ITERATION: 27, FOLD 5:
# Best model was found and saved in epoch 132 with val_loss: 32.801963806152344 and val_score: 6.653539657592773
# [6.596162796020508, 6.840442180633545, 6.830387115478516, 6.5798258781433105, 6.653539657592773] #
#
# ITERATION: 28, FOLD 1:
# Best model was found and saved in epoch 68 with val_loss: 36.57899856567383 and val_score: 6.753583908081055
# ITERATION: 28, FOLD 2:
# Best model was found and saved in epoch 544 with val_loss: 48.58896255493164 and val_score: 6.983737945556641
# ITERATION: 28, FOLD 3:
# Best model was found and saved in epoch 186 with val_loss: 43.045318603515625 and val_score: 6.936378002166748
# ITERATION: 28, FOLD 4:
# Best model was found and saved in epoch 51 with val_loss: 38.821414947509766 and val_score: 6.816717147827148
# ITERATION: 28, FOLD 5:
# Best model was found and saved in epoch 341 with val_loss: 42.930519104003906 and val_score: 6.813287258148193
# [6.753583908081055, 6.983737945556641, 6.936378002166748, 6.816717147827148, 6.813287258148193] #
#
# ITERATION: 29, FOLD 1:
# Best model was found and saved in epoch 366 with val_loss: 38.98234558105469 and val_score: 6.687742233276367
# ITERATION: 29, FOLD 2:
# Best model was found and saved in epoch 264 with val_loss: 50.39239501953125 and val_score: 6.828828811645508
# ITERATION: 29, FOLD 3:
# Best model was found and saved in epoch 301 with val_loss: 43.32088851928711 and val_score: 6.68103551864624
# ITERATION: 29, FOLD 4:
# Best model was found and saved in epoch 459 with val_loss: 41.49235153198242 and val_score: 6.618751525878906
# ITERATION: 29, FOLD 5:
# Best model was found and saved in epoch 348 with val_loss: 44.259578704833984 and val_score: 6.694889068603516
# [6.687742233276367, 6.828828811645508, 6.68103551864624, 6.618751525878906, 6.694889068603516] #
#
# ITERATION: 30, FOLD 1:
# Best model was found and saved in epoch 278 with val_loss: 37.90117645263672 and val_score: 6.571530342102051
# ITERATION: 30, FOLD 2:
# Best model was found and saved in epoch 301 with val_loss: 50.16550064086914 and val_score: 6.813135147094727
# ITERATION: 30, FOLD 3:
# Best model was found and saved in epoch 355 with val_loss: 44.91423034667969 and val_score: 6.732744216918945
# ITERATION: 30, FOLD 4:
# Best model was found and saved in epoch 198 with val_loss: 40.842552185058594 and val_score: 6.635713577270508
# ITERATION: 30, FOLD 5:
# Best model was found and saved in epoch 438 with val_loss: 43.44124221801758 and val_score: 6.656203269958496
# [6.571530342102051, 6.813135147094727, 6.732744216918945, 6.635713577270508, 6.656203269958496] #
#
# ITERATION: 31, FOLD 1:
# Best model was found and saved in epoch 333 with val_loss: 26.173120498657227 and val_score: 6.609639644622803
# ITERATION: 31, FOLD 2:
# Best model was found and saved in epoch 341 with val_loss: 35.106651306152344 and val_score: 6.869871616363525
# ITERATION: 31, FOLD 3:
# Best model was found and saved in epoch 156 with val_loss: 30.29331398010254 and val_score: 6.734760761260986
# ITERATION: 31, FOLD 4:
# Best model was found and saved in epoch 366 with val_loss: 28.038949966430664 and val_score: 6.620410919189453
# ITERATION: 31, FOLD 5:
# Best model was found and saved in epoch 114 with val_loss: 29.073101043701172 and val_score: 6.692702770233154
# [6.609639644622803, 6.869871616363525, 6.734760761260986, 6.620410919189453, 6.692702770233154] #
#
# ITERATION: 32, FOLD 1:
# Best model was found and saved in epoch 411 with val_loss: 42.9659309387207 and val_score: 6.791751861572266
# ITERATION: 32, FOLD 2:
# Best model was found and saved in epoch 555 with val_loss: 53.663169860839844 and val_score: 6.949027061462402
# ITERATION: 32, FOLD 3:
# Best model was found and saved in epoch 407 with val_loss: 47.15885925292969 and val_score: 6.846579074859619
# ITERATION: 32, FOLD 4:
# Best model was found and saved in epoch 624 with val_loss: 43.57278060913086 and val_score: 6.78498649597168
# ITERATION: 32, FOLD 5:
# Best model was found and saved in epoch 490 with val_loss: 47.631805419921875 and val_score: 6.8275957107543945
# [6.791751861572266, 6.949027061462402, 6.846579074859619, 6.78498649597168, 6.8275957107543945] #
#
# ITERATION: 33, FOLD 1:
# Best model was found and saved in epoch 250 with val_loss: 34.21989440917969 and val_score: 6.646848201751709
# ITERATION: 33, FOLD 2:
# Best model was found and saved in epoch 522 with val_loss: 45.619266510009766 and val_score: 6.842087745666504
# ITERATION: 33, FOLD 3:
# Best model was found and saved in epoch 168 with val_loss: 36.6967887878418 and val_score: 6.594533443450928
# ITERATION: 33, FOLD 4:
# Best model was found and saved in epoch 335 with val_loss: 38.5012092590332 and val_score: 6.695740222930908
# ITERATION: 33, FOLD 5:
# Best model was found and saved in epoch 238 with val_loss: 39.308753967285156 and val_score: 6.609244346618652
# [6.646848201751709, 6.842087745666504, 6.594533443450928, 6.695740222930908, 6.609244346618652] #
#
# ITERATION: 34, FOLD 1:
# Best model was found and saved in epoch 405 with val_loss: 33.18034362792969 and val_score: 6.743285179138184
# ITERATION: 34, FOLD 2:
# Best model was found and saved in epoch 301 with val_loss: 41.35670852661133 and val_score: 6.937645435333252
# ITERATION: 34, FOLD 3:
# Best model was found and saved in epoch 288 with val_loss: 34.49191665649414 and val_score: 6.754274368286133
# ITERATION: 34, FOLD 4:
# Best model was found and saved in epoch 287 with val_loss: 36.23379898071289 and val_score: 6.825566291809082
# ITERATION: 34, FOLD 5:
# Best model was found and saved in epoch 450 with val_loss: 40.1502685546875 and val_score: 6.867641925811768
# [6.743285179138184, 6.937645435333252, 6.754274368286133, 6.825566291809082, 6.867641925811768] #
#
# ITERATION: 35, FOLD 1:
# Best model was found and saved in epoch 525 with val_loss: 32.05689239501953 and val_score: 6.712378025054932
# ITERATION: 35, FOLD 2:
# Best model was found and saved in epoch 113 with val_loss: 39.82883834838867 and val_score: 6.836795330047607
# ITERATION: 35, FOLD 3:
# Best model was found and saved in epoch 131 with val_loss: 29.267417907714844 and val_score: 6.4736504554748535
# ITERATION: 35, FOLD 4:
# Best model was found and saved in epoch 182 with val_loss: 35.68854904174805 and val_score: 6.794832706451416
# ITERATION: 35, FOLD 5:
# Best model was found and saved in epoch 448 with val_loss: 34.590667724609375 and val_score: 6.520694732666016
# [6.712378025054932, 6.836795330047607, 6.4736504554748535, 6.794832706451416, 6.520694732666016] #
#
# ITERATION: 36, FOLD 1:
# Best model was found and saved in epoch 368 with val_loss: 39.25319290161133 and val_score: 6.679623603820801
# ITERATION: 36, FOLD 2:
# Best model was found and saved in epoch 369 with val_loss: 51.1983642578125 and val_score: 6.828424453735352
# ITERATION: 36, FOLD 3:
# Best model was found and saved in epoch 93 with val_loss: 45.8814697265625 and val_score: 6.785625457763672
# ITERATION: 36, FOLD 4:
# Best model was found and saved in epoch 329 with val_loss: 43.72916793823242 and val_score: 6.742281913757324
# ITERATION: 36, FOLD 5:
# Best model was found and saved in epoch 448 with val_loss: 43.16646957397461 and val_score: 6.639682769775391
# [6.679623603820801, 6.828424453735352, 6.785625457763672, 6.742281913757324, 6.639682769775391] #
#
# ITERATION: 37, FOLD 1:
# Best model was found and saved in epoch 492 with val_loss: 40.699851989746094 and val_score: 6.680955410003662
# ITERATION: 37, FOLD 2:
# Best model was found and saved in epoch 438 with val_loss: 50.27702331542969 and val_score: 6.784517765045166
# ITERATION: 37, FOLD 3:
# Best model was found and saved in epoch 99 with val_loss: 44.94775390625 and val_score: 6.719165802001953
# ITERATION: 37, FOLD 4:
# Best model was found and saved in epoch 430 with val_loss: 42.166046142578125 and val_score: 6.5873870849609375
# ITERATION: 37, FOLD 5:
# Best model was found and saved in epoch 60 with val_loss: 42.15654373168945 and val_score: 6.71709680557251
# [6.680955410003662, 6.784517765045166, 6.719165802001953, 6.5873870849609375, 6.71709680557251] #
#
# ITERATION: 38, FOLD 1:
# Best model was found and saved in epoch 250 with val_loss: 40.146461486816406 and val_score: 6.680758953094482
# ITERATION: 38, FOLD 2:
# Best model was found and saved in epoch 207 with val_loss: 53.45936584472656 and val_score: 6.90911340713501
# ITERATION: 38, FOLD 3:
# Best model was found and saved in epoch 271 with val_loss: 43.19551467895508 and val_score: 6.709300994873047
# ITERATION: 38, FOLD 4:
# Best model was found and saved in epoch 381 with val_loss: 44.8990364074707 and val_score: 6.7412190437316895
# ITERATION: 38, FOLD 5:
# Best model was found and saved in epoch 264 with val_loss: 46.26641845703125 and val_score: 6.7484893798828125
# [6.680758953094482, 6.90911340713501, 6.709300994873047, 6.7412190437316895, 6.7484893798828125] #
#
# ITERATION: 39, FOLD 1:
# Best model was found and saved in epoch 460 with val_loss: 30.964584350585938 and val_score: 6.647872447967529
# ITERATION: 39, FOLD 2:
# Best model was found and saved in epoch 361 with val_loss: 38.07570266723633 and val_score: 6.715968132019043
# ITERATION: 39, FOLD 3:
# Best model was found and saved in epoch 83 with val_loss: 36.27549743652344 and val_score: 6.75820255279541
# ITERATION: 39, FOLD 4:
# Best model was found and saved in epoch 196 with val_loss: 34.19935607910156 and val_score: 6.634195327758789
# ITERATION: 39, FOLD 5:
# Best model was found and saved in epoch 46 with val_loss: 36.14213943481445 and val_score: 6.725024223327637
# [6.647872447967529, 6.715968132019043, 6.75820255279541, 6.634195327758789, 6.725024223327637] #
#
# ITERATION: 40, FOLD 1:
# Best model was found and saved in epoch 351 with val_loss: 45.71720886230469 and val_score: 6.7546844482421875
# ITERATION: 40, FOLD 2:
# Best model was found and saved in epoch 337 with val_loss: 58.127254486083984 and val_score: 6.926182746887207
# ITERATION: 40, FOLD 3:
# Best model was found and saved in epoch 572 with val_loss: 51.53560256958008 and val_score: 6.783349990844727
# ITERATION: 40, FOLD 4:
# Best model was found and saved in epoch 451 with val_loss: 47.68487548828125 and val_score: 6.75024938583374
# ITERATION: 40, FOLD 5:
# Best model was found and saved in epoch 364 with val_loss: 54.491981506347656 and val_score: 6.780566692352295
# [6.7546844482421875, 6.926182746887207, 6.783349990844727, 6.75024938583374, 6.780566692352295] #
#
# ITERATION: 41, FOLD 1:
# Best model was found and saved in epoch 511 with val_loss: 31.00784683227539 and val_score: 6.648630142211914
# ITERATION: 41, FOLD 2:
# Best model was found and saved in epoch 453 with val_loss: 40.45862579345703 and val_score: 6.819034576416016
# ITERATION: 41, FOLD 3:
# Best model was found and saved in epoch 147 with val_loss: 35.97996520996094 and val_score: 6.701388835906982
# ITERATION: 41, FOLD 4:
# Best model was found and saved in epoch 385 with val_loss: 33.077857971191406 and val_score: 6.6493449211120605
# ITERATION: 41, FOLD 5:
# Best model was found and saved in epoch 118 with val_loss: 36.40673828125 and val_score: 6.734905242919922
# [6.648630142211914, 6.819034576416016, 6.701388835906982, 6.6493449211120605, 6.734905242919922] #
#
# ITERATION: 42, FOLD 1:
# Best model was found and saved in epoch 470 with val_loss: 31.603822708129883 and val_score: 6.657425880432129
# ITERATION: 42, FOLD 2:
# Best model was found and saved in epoch 464 with val_loss: 40.1568489074707 and val_score: 6.831043243408203
# ITERATION: 42, FOLD 3:
# Best model was found and saved in epoch 373 with val_loss: 36.67986297607422 and val_score: 6.73425817489624
# ITERATION: 42, FOLD 4:
# Best model was found and saved in epoch 451 with val_loss: 34.11769104003906 and val_score: 6.755015850067139
# ITERATION: 42, FOLD 5:
# Best model was found and saved in epoch 65 with val_loss: 34.36088180541992 and val_score: 6.6974921226501465
# [6.657425880432129, 6.831043243408203, 6.73425817489624, 6.755015850067139, 6.6974921226501465] #
#
# ITERATION: 43, FOLD 1:
# Best model was found and saved in epoch 47 with val_loss: 40.861454010009766 and val_score: 6.802060604095459
# ITERATION: 43, FOLD 2:
# Best model was found and saved in epoch 297 with val_loss: 51.03974533081055 and val_score: 6.863584995269775
# ITERATION: 43, FOLD 3:
# Best model was found and saved in epoch 126 with val_loss: 41.12019729614258 and val_score: 6.697689056396484
# ITERATION: 43, FOLD 4:
# Best model was found and saved in epoch 386 with val_loss: 41.08602523803711 and val_score: 6.617217540740967
# ITERATION: 43, FOLD 5:
# Best model was found and saved in epoch 357 with val_loss: 45.44012451171875 and val_score: 6.762150287628174
# [6.802060604095459, 6.863584995269775, 6.697689056396484, 6.617217540740967, 6.762150287628174] #
#
# ITERATION: 44, FOLD 1:
# Best model was found and saved in epoch 203 with val_loss: 31.572729110717773 and val_score: 6.68424129486084
# ITERATION: 44, FOLD 2:
# Best model was found and saved in epoch 331 with val_loss: 41.723968505859375 and val_score: 6.758598327636719
# ITERATION: 44, FOLD 3:
# Best model was found and saved in epoch 162 with val_loss: 33.341041564941406 and val_score: 6.64475154876709
# ITERATION: 44, FOLD 4:
# Best model was found and saved in epoch 408 with val_loss: 34.099273681640625 and val_score: 6.715956211090088
# ITERATION: 44, FOLD 5:
# Best model was found and saved in epoch 218 with val_loss: 33.386871337890625 and val_score: 6.707179546356201
# [6.68424129486084, 6.758598327636719, 6.64475154876709, 6.715956211090088, 6.707179546356201] #
#
# ITERATION: 45, FOLD 1:
# Best model was found and saved in epoch 453 with val_loss: 41.16046905517578 and val_score: 6.707228183746338
# ITERATION: 45, FOLD 2:
# Best model was found and saved in epoch 262 with val_loss: 51.64031219482422 and val_score: 6.779972076416016
# ITERATION: 45, FOLD 3:
# Best model was found and saved in epoch 156 with val_loss: 44.11781311035156 and val_score: 6.727906227111816
# ITERATION: 45, FOLD 4:
# Best model was found and saved in epoch 641 with val_loss: 41.53446578979492 and val_score: 6.620810031890869
# ITERATION: 45, FOLD 5:
# Best model was found and saved in epoch 274 with val_loss: 42.776302337646484 and val_score: 6.640442848205566
# [6.707228183746338, 6.779972076416016, 6.727906227111816, 6.620810031890869, 6.640442848205566] #
#
# ITERATION: 46, FOLD 1:
# Best model was found and saved in epoch 240 with val_loss: 41.445220947265625 and val_score: 6.61893367767334
# ITERATION: 46, FOLD 2:
# Best model was found and saved in epoch 337 with val_loss: 60.15580368041992 and val_score: 6.8603901863098145
# ITERATION: 46, FOLD 3:
# Best model was found and saved in epoch 243 with val_loss: 43.8525505065918 and val_score: 6.595699310302734
# ITERATION: 46, FOLD 4:
# Best model was found and saved in epoch 143 with val_loss: 46.50458908081055 and val_score: 6.614329814910889
# ITERATION: 46, FOLD 5:
# Best model was found and saved in epoch 280 with val_loss: 46.841758728027344 and val_score: 6.586248397827148
# [6.61893367767334, 6.8603901863098145, 6.595699310302734, 6.614329814910889, 6.586248397827148] #
#
# ITERATION: 47, FOLD 1:
# Best model was found and saved in epoch 152 with val_loss: 30.269346237182617 and val_score: 6.591867446899414
# ITERATION: 47, FOLD 2:
# Best model was found and saved in epoch 161 with val_loss: 39.93703079223633 and val_score: 6.832219123840332
# ITERATION: 47, FOLD 3:
# Best model was found and saved in epoch 135 with val_loss: 34.813480377197266 and val_score: 6.672901153564453
# ITERATION: 47, FOLD 4:
# Best model was found and saved in epoch 142 with val_loss: 33.20216369628906 and val_score: 6.665290832519531
# ITERATION: 47, FOLD 5:
# Best model was found and saved in epoch 304 with val_loss: 40.452613830566406 and val_score: 6.779595375061035
# [6.591867446899414, 6.832219123840332, 6.672901153564453, 6.665290832519531, 6.779595375061035] #
#
# ITERATION: 48, FOLD 1:
# Best model was found and saved in epoch 229 with val_loss: 29.179330825805664 and val_score: 6.787471771240234
# ITERATION: 48, FOLD 2:
# Best model was found and saved in epoch 555 with val_loss: 37.16001510620117 and val_score: 6.987467288970947
# ITERATION: 48, FOLD 3:
# Best model was found and saved in epoch 273 with val_loss: 32.64838409423828 and val_score: 6.878538608551025
# ITERATION: 48, FOLD 4:
# Best model was found and saved in epoch 188 with val_loss: 30.655254364013672 and val_score: 6.810201644897461
# ITERATION: 48, FOLD 5:
# Best model was found and saved in epoch 190 with val_loss: 30.90605926513672 and val_score: 6.821075439453125
# [6.787471771240234, 6.987467288970947, 6.878538608551025, 6.810201644897461, 6.821075439453125] #
#
# ITERATION: 49, FOLD 1:
# Best model was found and saved in epoch 375 with val_loss: 27.834264755249023 and val_score: 6.640369415283203
# ITERATION: 49, FOLD 2:
# Best model was found and saved in epoch 250 with val_loss: 33.977203369140625 and val_score: 6.805153846740723
# ITERATION: 49, FOLD 3:
# Best model was found and saved in epoch 194 with val_loss: 30.57554054260254 and val_score: 6.617702484130859
# ITERATION: 49, FOLD 4:
# Best model was found and saved in epoch 253 with val_loss: 27.804597854614258 and val_score: 6.608942985534668
# ITERATION: 49, FOLD 5:
# Best model was found and saved in epoch 500 with val_loss: 32.09488296508789 and val_score: 6.746860504150391
# [6.640369415283203, 6.805153846740723, 6.617702484130859, 6.608942985534668, 6.746860504150391] #
#
# ITERATION: 50, FOLD 1:
# Best model was found and saved in epoch 251 with val_loss: 35.30613708496094 and val_score: 6.654675483703613
# ITERATION: 50, FOLD 2:
# Best model was found and saved in epoch 372 with val_loss: 46.830596923828125 and val_score: 6.717078685760498
# ITERATION: 50, FOLD 3:
# Best model was found and saved in epoch 131 with val_loss: 40.51971435546875 and val_score: 6.79300594329834
# ITERATION: 50, FOLD 4:
# Best model was found and saved in epoch 285 with val_loss: 40.3774299621582 and val_score: 6.741965293884277
# ITERATION: 50, FOLD 5:
# Best model was found and saved in epoch 303 with val_loss: 41.587501525878906 and val_score: 6.597349166870117
# [6.654675483703613, 6.717078685760498, 6.79300594329834, 6.741965293884277, 6.597349166870117] #
#
# ITERATION: 51, FOLD 1:
# Best model was found and saved in epoch 463 with val_loss: 32.0224609375 and val_score: 6.711762428283691
# ITERATION: 51, FOLD 2:
# Best model was found and saved in epoch 192 with val_loss: 40.967803955078125 and val_score: 6.871487140655518
# ITERATION: 51, FOLD 3:
# Best model was found and saved in epoch 203 with val_loss: 36.225616455078125 and val_score: 6.688763618469238
# ITERATION: 51, FOLD 4:
# Best model was found and saved in epoch 398 with val_loss: 32.69687271118164 and val_score: 6.649166107177734
# ITERATION: 51, FOLD 5:
# Best model was found and saved in epoch 97 with val_loss: 36.0001220703125 and val_score: 6.842136859893799
# [6.711762428283691, 6.871487140655518, 6.688763618469238, 6.649166107177734, 6.842136859893799] #
#
# ITERATION: 52, FOLD 1:
# Best model was found and saved in epoch 333 with val_loss: 39.75431442260742 and val_score: 6.640527248382568
# ITERATION: 52, FOLD 2:
# Best model was found and saved in epoch 409 with val_loss: 50.27840805053711 and val_score: 6.840310573577881
# ITERATION: 52, FOLD 3:
# Best model was found and saved in epoch 218 with val_loss: 42.69300842285156 and val_score: 6.680602550506592
# ITERATION: 52, FOLD 4:
# Best model was found and saved in epoch 130 with val_loss: 45.74872589111328 and val_score: 6.750433444976807
# ITERATION: 52, FOLD 5:
# Best model was found and saved in epoch 144 with val_loss: 47.17832946777344 and val_score: 6.704119682312012
# [6.640527248382568, 6.840310573577881, 6.680602550506592, 6.750433444976807, 6.704119682312012] #
#
# ITERATION: 53, FOLD 1:
# Best model was found and saved in epoch 562 with val_loss: 41.32706069946289 and val_score: 6.706949234008789
# ITERATION: 53, FOLD 2:
# Best model was found and saved in epoch 271 with val_loss: 50.98728561401367 and val_score: 6.859695911407471
# ITERATION: 53, FOLD 3:
# Best model was found and saved in epoch 484 with val_loss: 44.36229705810547 and val_score: 6.776401996612549
# ITERATION: 53, FOLD 4:
# Best model was found and saved in epoch 451 with val_loss: 44.11958694458008 and val_score: 6.758856773376465
# ITERATION: 53, FOLD 5:
# Best model was found and saved in epoch 55 with val_loss: 44.58420181274414 and val_score: 6.764739513397217
# [6.706949234008789, 6.859695911407471, 6.776401996612549, 6.758856773376465, 6.764739513397217] #
#
# ITERATION: 54, FOLD 1:
# Best model was found and saved in epoch 292 with val_loss: 38.480350494384766 and val_score: 6.598875522613525
# ITERATION: 54, FOLD 2:
# Best model was found and saved in epoch 293 with val_loss: 51.11722946166992 and val_score: 6.836859226226807
# ITERATION: 54, FOLD 3:
# Best model was found and saved in epoch 210 with val_loss: 44.116493225097656 and val_score: 6.623899936676025
# ITERATION: 54, FOLD 4:
# Best model was found and saved in epoch 415 with val_loss: 41.65774154663086 and val_score: 6.66993522644043
# ITERATION: 54, FOLD 5:
# Best model was found and saved in epoch 143 with val_loss: 44.8543701171875 and val_score: 6.768373489379883
# [6.598875522613525, 6.836859226226807, 6.623899936676025, 6.66993522644043, 6.768373489379883] #
#
# ITERATION: 55, FOLD 1:
# Best model was found and saved in epoch 455 with val_loss: 46.30249786376953 and val_score: 6.728461742401123
# ITERATION: 55, FOLD 2:
# Best model was found and saved in epoch 581 with val_loss: 59.236480712890625 and val_score: 6.904050350189209
# ITERATION: 55, FOLD 3:
# Best model was found and saved in epoch 419 with val_loss: 49.55379104614258 and val_score: 6.668584823608398
# ITERATION: 55, FOLD 4:
# Best model was found and saved in epoch 51 with val_loss: 47.97654724121094 and val_score: 6.739878177642822
# ITERATION: 55, FOLD 5:
# Best model was found and saved in epoch 67 with val_loss: 56.218963623046875 and val_score: 6.811326026916504
# [6.728461742401123, 6.904050350189209, 6.668584823608398, 6.739878177642822, 6.811326026916504] #
#
# ITERATION: 56, FOLD 1:
# Best model was found and saved in epoch 153 with val_loss: 40.77314376831055 and val_score: 6.757246971130371
# ITERATION: 56, FOLD 2:
# Best model was found and saved in epoch 269 with val_loss: 51.24871063232422 and val_score: 6.912248134613037
# ITERATION: 56, FOLD 3:
# Best model was found and saved in epoch 237 with val_loss: 43.323219299316406 and val_score: 6.696926116943359
# ITERATION: 56, FOLD 4:
# Best model was found and saved in epoch 253 with val_loss: 44.9466667175293 and val_score: 6.72409725189209
# ITERATION: 56, FOLD 5:
# Best model was found and saved in epoch 246 with val_loss: 56.50529861450195 and val_score: 6.9652838706970215
# [6.757246971130371, 6.912248134613037, 6.696926116943359, 6.72409725189209, 6.9652838706970215] #
#
# ITERATION: 57, FOLD 1:
# Best model was found and saved in epoch 564 with val_loss: 40.27997970581055 and val_score: 6.682399272918701
# ITERATION: 57, FOLD 2:
# Best model was found and saved in epoch 301 with val_loss: 50.10578155517578 and val_score: 6.736620903015137
# ITERATION: 57, FOLD 3:
# Best model was found and saved in epoch 301 with val_loss: 42.57825469970703 and val_score: 6.634182453155518
# ITERATION: 57, FOLD 4:
# Best model was found and saved in epoch 463 with val_loss: 41.80319595336914 and val_score: 6.6822638511657715
# ITERATION: 57, FOLD 5:
# Best model was found and saved in epoch 145 with val_loss: 46.620540618896484 and val_score: 6.792935371398926
# [6.682399272918701, 6.736620903015137, 6.634182453155518, 6.6822638511657715, 6.792935371398926] #
#
# ITERATION: 58, FOLD 1:
# Best model was found and saved in epoch 499 with val_loss: 42.753944396972656 and val_score: 6.802251815795898
# ITERATION: 58, FOLD 2:
# Best model was found and saved in epoch 397 with val_loss: 54.86654281616211 and val_score: 7.017332077026367
# ITERATION: 58, FOLD 3:
# Best model was found and saved in epoch 76 with val_loss: 45.896446228027344 and val_score: 6.857244491577148
# ITERATION: 58, FOLD 4:
# Best model was found and saved in epoch 508 with val_loss: 46.6591796875 and val_score: 6.865879058837891
# ITERATION: 58, FOLD 5:
# Best model was found and saved in epoch 566 with val_loss: 46.63151931762695 and val_score: 6.797779560089111
# [6.802251815795898, 7.017332077026367, 6.857244491577148, 6.865879058837891, 6.797779560089111] #
#
# ITERATION: 59, FOLD 1:
# Best model was found and saved in epoch 462 with val_loss: 45.500938415527344 and val_score: 6.597589492797852
# ITERATION: 59, FOLD 2:
# Best model was found and saved in epoch 434 with val_loss: 58.13005447387695 and val_score: 6.857489109039307
# ITERATION: 59, FOLD 3:
# Best model was found and saved in epoch 373 with val_loss: 46.115089416503906 and val_score: 6.702526092529297
# ITERATION: 59, FOLD 4:
# Best model was found and saved in epoch 433 with val_loss: 48.84638595581055 and val_score: 6.674591064453125
# ITERATION: 59, FOLD 5:
# Best model was found and saved in epoch 341 with val_loss: 57.117820739746094 and val_score: 6.81026029586792
# [6.597589492797852, 6.857489109039307, 6.702526092529297, 6.674591064453125, 6.81026029586792] #

# %%
end_time = time.time()
print (f"It took {(end_time - start_time)/60/60:.1f} hours. Meaning {(end_time - start_time)/(ITERATIONS * EPOCHS):.2f} seconds per iteration @ {NFOLDS} folds and {EPOCHS} epochs.")
# Out:
# It took 6.4 hours. Meaning 0.48 seconds per iteration @ 5 folds and 800 epochs.

# %% [markdown]
# # Evaluation & Ensemble
# ### WELL DONE! Grid Search & Training COMPLETED!
#
# We are currently using an *average of our predictions over all folds* in each ITERATION.
# We can additionally average those results/predicstion using several of the best iterations
#
# Let's use the best results to make our predictions for submission. In addition, we are going to save the results_df to be able to check for the best parameters after the commit is completed.
#
# Another Notebook explaning how to do ensembling in this competition can be found [here.](https://www.kaggle.com/ChristianDenich/multi-model-ensembling-evaluation)

# %%
# Sort the results based OOF-Score
results_df.sort_values('val_score', ascending = True, inplace = True)
results_df.reset_index(inplace = True)
# saving dataframe
results_df.to_csv('results_df_with_params')
results_df.head()
# Out:
#    index iteration val_score  \
# 0     19        19   6.64649
# 1     21        21   6.65156
# 2     46        46   6.65512
# 3      8         8   6.66654
# 4     35        35   6.66767
#
#                                               params  \
# 0  {'NFOLDS': {5}, 'EPOCHS': {800}, 'batch_size':...
# 1  {'NFOLDS': {5}, 'EPOCHS': {800}, 'batch_size':...
# 2  {'NFOLDS': {5}, 'EPOCHS': {800}, 'batch_size':...
# 3  {'NFOLDS': {5}, 'EPOCHS': {800}, 'batch_size':...
# 4  {'NFOLDS': {5}, 'EPOCHS': {800}, 'batch_size':...
#
#                                     test_predictions
# 0  [[2607.6910400390625, 2727.9849243164062, 2882...
# 1  [[2629.2569580078125, 2788.6072998046875, 2916...
# 2  [[2615.5126037597656, 2758.6249389648438, 2930...
# 3  [[2638.50390625, 2774.1893310546875, 2942.4515...
# 4  [[2587.879150390625, 2731.0481567382812, 2919....

# %% [markdown]
# ### Average the best models

# %%
## Choose how many of the best models shall be used for ensembling/averaging
N_best_models = 3

# initialize/reset test_preds array
test_preds = np.zeros((X_test.shape[0], 3))

# add up best predictions and average afterwards
for model in range(N_best_models):
    test_preds += results_df.loc[model, 'test_predictions']

test_preds /= N_best_models

# %% [markdown]
# ### Prepare submission file
# In the next section we are going to use the ```train_preds``` to calculate the optimized sigma, which is a measure for certainty or rather uncertainty. We can do that, as we have both: the model's estimate and the real data. We subtract the lower quartile from the upper quartile (defined in the loss function) and average it.

# %%
## FIND OPTIMIZED STANDARD-DEVIATION
sigma_opt = mean_absolute_error(y, train_preds[:,1])
sigma_uncertain = train_preds[:,2] - train_preds[:,0]
sigma_mean = np.mean(sigma_uncertain)
print(sigma_opt, sigma_mean)
# Out:
# 135.3068968931316 326.7425469115813

# %%
## PREPARE SUBMISSION FILE WITH OUR PREDICTIONS
sub['FVC1'] = test_preds[:, 1]
sub['Confidence1'] = test_preds[:,2] - test_preds[:,0]

# get rid of unused data and show some non-empty data
submission = sub[['Patient_Week','FVC','Confidence','FVC1','Confidence1']].copy()
submission.loc[~submission.FVC1.isnull()].head(10)
# Out:
#                        Patient_Week   FVC  Confidence         FVC1  \
# 1535  ID00419637202311204720264_-12  3020       100.0  2758.405721
# 1536  ID00419637202311204720264_-11  3020       100.0  2754.427836
# 1537  ID00419637202311204720264_-10  3020       100.0  2750.524211
# 1538   ID00419637202311204720264_-9  3020       100.0  2746.695943
# 1539   ID00419637202311204720264_-8  3020       100.0  2742.889974
# 1540   ID00419637202311204720264_-7  3020       100.0  2739.186605
# 1541   ID00419637202311204720264_-6  3020       100.0  2736.192383
# 1542   ID00419637202311204720264_-5  3020       100.0  2733.859985
# 1543   ID00419637202311204720264_-4  3020       100.0  2731.801229
# 1544   ID00419637202311204720264_-3  3020       100.0  2729.898438
#
#       Confidence1
# 1535   292.486969
# 1536   292.523804
# 1537   292.562714
# 1538   292.608602
# 1539   292.645925
# 1540   292.624003
# 1541   292.529297
# 1542   292.462219
# 1543   292.400258
# 1544   292.338694

# %%
submission.loc[~submission.FVC1.isnull(),'FVC'] = submission.loc[~submission.FVC1.isnull(),'FVC1']

if sigma_mean < 70:
    submission['Confidence'] = sigma_opt
else:
    submission.loc[~submission.FVC1.isnull(),'Confidence'] = submission.loc[~submission.FVC1.isnull(),'Confidence1']

# %% [markdown]
# Okay, we made it! Let's finally check our stats and submit it!

# %%
submission.head()
# Out:
#                        Patient_Week          FVC  Confidence         FVC1  \
# 1535  ID00419637202311204720264_-12  2758.405721  292.486969  2758.405721
# 1536  ID00419637202311204720264_-11  2754.427836  292.523804  2754.427836
# 1537  ID00419637202311204720264_-10  2750.524211  292.562714  2750.524211
# 1538   ID00419637202311204720264_-9  2746.695943  292.608602  2746.695943
# 1539   ID00419637202311204720264_-8  2742.889974  292.645925  2742.889974
#
#       Confidence1
# 1535   292.486969
# 1536   292.523804
# 1537   292.562714
# 1538   292.608602
# 1539   292.645925

# %%
submission.describe().T
# Out:
#              count         mean         std          min          25%  \
# FVC          730.0  2683.171806  364.026589  1949.911458  2696.430283
# Confidence   730.0   309.135381   57.103777   241.659149   284.901126
# FVC1         730.0  2683.171806  364.026589  1949.911458  2696.430283
# Confidence1  730.0   309.135381   57.103777   241.659149   284.901126
#
#                      50%          75%          max
# FVC          2750.682933  2871.763926  3195.224040
# Confidence    292.298269   335.412827   595.550944
# FVC1         2750.682933  2871.763926  3195.224040
# Confidence1   292.298269   335.412827   595.550944

# %% [markdown]
# In the following last step we overwrite our predictions with the known data from the orginal submission file to not waste known data.

# %%
org_test = pd.read_csv('../input/osic-pulmonary-fibrosis-progression/test.csv')

for i in range(len(org_test)):
    submission.loc[submission['Patient_Week']==org_test.Patient[i]+'_'+str(org_test.Weeks[i]), 'FVC'] = org_test.FVC[i]
    submission.loc[submission['Patient_Week']==org_test.Patient[i]+'_'+str(org_test.Weeks[i]), 'Confidence'] = 70

# %%
submission[["Patient_Week","FVC","Confidence"]].to_csv("submission.csv", index = False)
